# %% [markdown]
# ### Q1. Check if a number is positive, negative, or zero
# **Topic:** Conditional Statements | **Level:** Easy

# %%
num=int(input("enter the number"))
if num > 0:
    print("positive")
elif num < 0:
    print("negative")
else:
    print("zero")
# Out:
# negative

# %% [markdown]
# ### Q2. Check if a number is even or odd
# **Topic:** Conditional Statements | **Level:** Easy

# %%
# your code here
n=int(input("enter the number"))
if n%2 == 0 :
    print("even number")
else :
    print("odd number")
# Out:
# odd number

# %% [markdown]
# ### Q3. Check if a number is divisible by 2
# **Topic:** Conditional Statements | **Level:** Easy

# %%
n=int(input("enter your number"))
if n % 2 == 0:
    print("its divisible")
else :
    print("not divisible")
# Out:
# not divisible

# %% [markdown]
# ### Q4. Check if a number is divisible by 3
# **Topic:** Conditional Statements | **Level:** Easy

# %%
# your code here
n=int(input("enter your number"))
if n % 3 == 0:
    print("its divisible")
else :
    print("not divisible")
# Out:
# not divisible

# %% [markdown]
# ### Q5. Check if a number is divisible by 5
# **Topic:** Conditional Statements | **Level:** Easy

# %%
# your code here
n=int(input("enter the number"))
if n%5==0 :
 print ("divisible by 5")
# Out:
# divisible by 5

# %% [markdown]
# ### Q6. Check if a number is divisible by both 2 and 3
# **Topic:** Conditional Statements | **Level:** Easy

# %%
n=(int(input("enter your number")))
if n%2==0 and n%3==0 :
    print("divisible")
else:
  print  ("not divisible")
# Out:
# not divisible

# %% [markdown]
# ### Q7. Check if a number is divisible by either 2 or 5
# **Topic:** Conditional Statements | **Level:** Easy

# %%
n=(int(input("enter your number")))
if n%2==0 and n%5==0 :
    print("divi")
else:
    print("not divi")
# Out:
# divi

# %% [markdown]
# ### Q8. Find the larger of two numbers
# **Topic:** Conditional Statements | **Level:** Easy

# %%
a=int(input("enter your no."))
b=int(input("enter your no."))
if a >b:
    print("a is big")
else :
    print("b is biggie")
# Out:
# a is big

# %% [markdown]
# ### Q9. Find the smaller of two numbers
# **Topic:** Conditional Statements | **Level:** Easy

# %%
n=int(input("enter your number"))
n1=int(input("enter your number"))
if n < n1:
    print(" n is small")
else:
    print("n1 is small")
# Out:
# n1 is small

# %% [markdown]
# ### Q10. Check whether two numbers are equal
# **Topic:** Conditional Statements | **Level:** Easy

# %%
a=int(input("enter your no."))
b=int(input("enter your no."))
if a==b:
    print("both equal")
else:
    print("not equal")
# Out:
# not equal

# %% [markdown]
# ### Q11. Find the largest of three numbers
# **Topic:** Conditional Statements | **Level:** Easy

# %%
a=int(input("enter your no."))
b=int(input("enter your no."))
c=int(input("enter your no."))
if a>b and a>c:
    print("a is big")
elif b>a and b>c :
    print("b is greater")
else :
    print("c is greater")
# Out:
# a is big

# %% [markdown]
# ### Q12. Find the smallest of three numbers
# **Topic:** Conditional Statements | **Level:** Easy

# %%
a=int((input("enter the number")))
b=int(input("enter the number"))
c=int(input("enter the number"))
if a<b and a<c :
    print("a is smaller")
elif b<a and b<c :
    print("b is smaller")
else:
    print("c is smaller")
# Out:
# c is smaller

# %% [markdown]
# ### Q13. Find the middle value among three numbers
# **Topic:** Conditional Statements | **Level:** Easy

# %%
a=int(input("enter your no."))
b=int(input("enter your no."))
c=int(input("enter your no."))

if (a > b > c) or (c > b > a):
    print("b is the middle no.")

elif (b > a > c) or (c > a > b):
    print("a is the middle no.")

else:
    print("c is the middle no.")
# Out:
# a is the middle no.

# %% [markdown]
# ### Q14. Check if a number is a single-digit number
# **Topic:** Conditional Statements | **Level:** Easy

# %%
n=int(input("enter the number"))
if -9 <=n and n<=9:
    print("n is a single digit  number")
# Out:
# n is a single digit  number

# %% [markdown]
# ### Q15. Check if a number is a two-digit number
# **Topic:** Conditional Statements | **Level:** Easy

# %%
# your code here
n=int(input("enter the number"))
if -99<=n <=-10  or 10 <=n <=99 :
    print("n is 2 digit number")

# %% [markdown]
# ### Q16. Check if a number is a three-digit number
# **Topic:** Conditional Statements | **Level:** Easy

# %%
n=int(input("enter the number"))
if -999<=n<=-100 and 100<=n<=999:
    print("n is 3 digit value")
# Out:
# n is 3 digit value

# %% [markdown]
# ### Q17. Check if a number lies between 1 and 100
# **Topic:** Conditional Statements | **Level:** Easy

# %%
n=int(input("enter your number"))
if 1<=n<=100:
    print("n is between 1 and 100")

# %% [markdown]
# ### Q18. Check if a number is a multiple of 7
# **Topic:** Conditional Statements | **Level:** Easy

# %%
n=int(input("enter your number"))
if n%7==0 :
    print("7 is muliple of n")
# Out:
# 7 is muliple of n

# %% [markdown]
# ### Q19. Check if a number is divisible by 2 but not by 4
# **Topic:** Conditional Statements | **Level:** Easy

# %%
n=int(input("enter your number"))
if n%2==0 and n%4!=0:   
    print("n is divisible by 2 but not by 4")
# Out:
# n is divisible by 2 but not by 4

# %% [markdown]
# ### Q20. Check if a number is divisible by 4 or 6
# **Topic:** Conditional Statements | **Level:** Easy

# %%
n=int(input("enter your number"))
if n%4==0 and n%6!= 0 :
    print("n is divisible by 4 but not by 6 ")

# %% [markdown]
# ### Q21. Check if a year is a leap year
# **Topic:** Conditional Statements | **Level:** Medium

# %%
n=int(input("enter your year"))
if n%4==0 and  n%100!=0 or n%400==0 :
    print("its leap year")

# %% [markdown]
# ### Q22. Check if a number is a factor of another number
# **Topic:** Conditional Statements | **Level:** Easy

# %%
a=int(input("enter your number"))
b=int(input("enter your number"))
if b%a==0 :
    print("a is factor of b")
else:
    print("not")
# Out:
# a is factor of b

# %% [markdown]
# ### Q23. Compare two numbers and print their difference
# **Topic:** Conditional Statements | **Level:** Easy

# %%
a=int(input("enter your number"))
b=int(input("enter your number"))
if a==b :
    print("equal")
else:
    
    print(a-b)
# Out:
# -3

# %% [markdown]
# ### Q24. Check if three sides can form a triangle
# **Topic:** Conditional Statements | **Level:** Medium

# %%
a=2
b=3
c=4
if a+b>c and b+c >a  and a+c >b:
    print("traiangle can be formed")
# Out:
# traiangle can be formed

# %% [markdown]
# ### Q25. Classify a triangle based on sides
# **Topic:** Conditional Statements | **Level:** Medium

# %%
a=int(input("enter a number"))
b=int(input("enter a numbeer"))
c=int(input("enter a number"))
if a==b==c:
    print("equilance triangle")
elif a==b!=c or a!=b==c or a==c!=b:
    print("2 sides")
else:
    print("no sides equal")
# Out:
# no sides equal

# %% [markdown]
# ### Q26. Print numbers from 1 to N
# **Topic:** Loops | **Level:** Easy

# %%
n=5
for i in range (n+1):
    print (i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# ### Q27. Print numbers from N to 1
# **Topic:** Loops | **Level:** Easy

# %%
n=5
for i in range (n-1+1,0,-1):
 print(i)
# Out:
# 5
# 4
# 3
# 2
# 1

# %% [markdown]
# ### Q28. Print all even numbers from 1 to N
# **Topic:** Loops | **Level:** Easy

# %%
n=10
for i in range (1,n+1,1):
 if i%2==0:
   print(i)
# Out:
# 2
# 4
# 6
# 8
# 10

# %% [markdown]
# ### Q29. Print all odd numbers from 1 to N
# **Topic:** Loops | **Level:** Easy

# %%
n=10
for i in range (1,n+1,1):
    if i%2!=0:
        print(i)
# Out:
# 1
# 3
# 5
# 7
# 9

# %% [markdown]
# ### Q30. Print all multiples of 5 up to N
# **Topic:** Loops | **Level:** Easy

# %%
n=20
for i in range (5,n+1,5):
    print (i)
# Out:
# 5
# 10
# 15
# 20

# %% [markdown]
# ### Q31. Print all multiples of 7 up to N
# **Topic:** Loops | **Level:** Easy

# %%
# your code here
n=30
for i in range (7,n+1,7):
    print(i)
# Out:
# 7
# 14
# 21
# 28

# %% [markdown]
# ### Q32. Find the sum of numbers from 1 to N
# **Topic:** Loops | **Level:** Easy

# %%
n=3
sum=0
for i in range (1,n+1):
    sum=sum+i
print (sum)
# Out:
# 6

# %% [markdown]
# ### Q33. Find the product of numbers from 1 to N
# **Topic:** Loops | **Level:** Easy

# %%
n=4
prod=1
for i in range (1,n+1):
    prod=prod*i
print (prod)
# Out:
# 24

# %% [markdown]
# ### Q34. Count numbers divisible by 3 from 1 to N
# **Topic:** Loops | **Level:** Easy

# %%
n=15
for i in range (3,n+1,3):
    print (i)
# Out:
# 3
# 6
# 9
# 12
# 15

# %% [markdown]
# ### Q35. Count even numbers from 1 to N
# **Topic:** Loops | **Level:** Easy

# %%
# your code here
n=8
for i in range(2,n+1,2):
    print (i)
# Out:
# 2
# 4
# 6
# 8

# %% [markdown]
# ### Q36. Count odd numbers from 1 to N
# **Topic:** Loops | **Level:** Easy

# %%
# your code here
n=7
for i in range (1,n+1,1):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7

# %% [markdown]
# ### Q37. Find the sum of even numbers from 1 to N
# **Topic:** Loops | **Level:** Easy

# %%
n=6
sum=0
for i in range(2,n+1,2):
    sum+=i
print (sum)
# Out:
# 12

# %% [markdown]
# ### Q38. Find the sum of odd numbers from 1 to N
# **Topic:** Loops | **Level:** Easy

# %%
n=5

sum=0
for i in range (1,n+1,2):
    sum+=i
print (sum)
# Out:
# 9

# %% [markdown]
# ### Q39. Print squares from 1 to N
# **Topic:** Loops | **Level:** Easy

# %%
n=3

for i in range (1,n+1,1):
    print(i**2)
# Out:
# 1
# 4
# 9

# %% [markdown]
# ### Q40. Print cubes from 1 to N
# **Topic:** Loops | **Level:** Easy

# %%
n=3

for i in range (1,n+1,1):
    print(i**3)
# Out:
# 1
# 8
# 27

# %% [markdown]
# ### Q41. Print all numbers divisible by both 3 and 5
# **Topic:** Loops | **Level:** Easy

# %%
n=30
for i in range(1,n+1,1):
    if i%3==0 and i%5==0:
        print(i)
# Out:
# 15
# 30

# %% [markdown]
# ### Q42. Print all numbers divisible by 4 but not 8
# **Topic:** Loops | **Level:** Medium

# %%
n=20
for i in range (1,n+1,1):
 if i%4==0 and i%8!=0:
    print (i)
# Out:
# 4
# 12
# 20

# %% [markdown]
# ### Q43. Count numbers divisible by 2 and 5 in a range
# **Topic:** Loops | **Level:** Medium

# %%
start=1
end=20
for i in range (start,end+1):
    if i%2==0 and i%5!=0:
        print (i)
# Out:
# 2
# 4
# 6
# 8
# 12
# 14
# 16
# 18

# %% [markdown]
# ### Q44. Print all numbers divisible by 9 in a range
# **Topic:** Loops | **Level:** Easy

# %%
start=1
end=30
for i in range(start,end):
    if i % 9==0:
        print(i)
# Out:
# 9
# 18
# 27

# %% [markdown]
# ### Q45. Find the average of numbers from 1 to N
# **Topic:** Loops | **Level:** Easy

# %%
start=1
end=5
avg=0
sum=0
for i in range (start,end+1):
    sum+=i
avg=sum/(end-start+1)
print (avg)
# Out:
# 3.0

# %% [markdown]
# ### Q46. Count numbers between A and B
# **Topic:** Loops | **Level:** Easy

# %%
a=1
b=15
num=0
num=b-a+1
print(num)
# Out:
# 15

# %% [markdown]
# ### Q47. Print all numbers between A and B
# **Topic:** Loops | **Level:** Easy

# %%
# your code here
a=1
b=5
for i in range(a,b+1):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# ### Q48. Find the sum of multiples of 4 up to N
# **Topic:** Loops | **Level:** Easy

# %%
n=8
sum=0
for i in range (n+1):
    if i%4==0:
        sum+=i
print(sum)
# Out:
# 12

# %% [markdown]
# ### Q49. Print all perfect squares up to N
# **Topic:** Loops | **Level:** Medium

# %%
start=1
end=20
for i in range(start,end+1):
    if i * i <=end :
      print(i, " is a perfect square")
# Out:
# 1  is a perfect square
# 2  is a perfect square
# 3  is a perfect square
# 4  is a perfect square

# %% [markdown]
# ### Q50. Print all perfect cubes up to N
# **Topic:** Loops | **Level:** Medium

# %%
start=1
end=30
for i in range(start,end+1):
    if i*i*i<=end:
        print(i,"is perfecrt cube")
# Out:
# 1 is perfecrt cube
# 2 is perfecrt cube
# 3 is perfecrt cube

# %% [markdown]
# ### Q51. Count digits in a number
# **Topic:** Digit Manipulation | **Level:** Easy

# %%
n=111111
count=0
while n>0:
    count+=1
    n=n//10
       
print(count)
# Out:
# 6

# %% [markdown]
# ### Q52. Find the sum of digits
# **Topic:** Digit Manipulation | **Level:** Easy

# %%
n=1234
sum=0
while n>0:
    digit=n%10
    sum+=digit
    n=n//10
print (sum)
# Out:
# 10

# %% [markdown]
# ### Q53. Find the product of digits
# **Topic:** Digit Manipulation | **Level:** Easy

# %%
n=1234
prod=1
while n>0:
    digit =n % 10
    prod*=digit
    n=n//10
print(prod)
# Out:
# 24

# %% [markdown]
# ### Q54. Reverse a number
# **Topic:** Digit Manipulation | **Level:** Easy

# %%
n=123
rev=0
while n>0:
    digit=n%10
    rev=rev*10 +digit
    n=n//10
print(rev)
# Out:
# 321

# %% [markdown]
# ### Q55. Check if a number is a palindrome
# **Topic:** Digit Manipulation | **Level:** Medium

# %%
n=131
org=131
rev=0
while n>0:
    digit=n%10
    rev=rev*10+digit
    n=n//10

if rev  == org :
        print("its palindrome")
# Out:
# its palindrome

# %% [markdown]
# ### Q56. Find the first digit
# **Topic:** Digit Manipulation | **Level:** Easy

# %% [markdown]
# ### Q57. Find the last digit
# **Topic:** Digit Manipulation | **Level:** Easy

# %%
n=123489

n=n%10
print (n)
# Out:
# 9

# %% [markdown]
# ### Q58. Find the largest digit
# **Topic:** Digit Manipulation | **Level:** Medium

# %%
n=1987432

max=0
while n>0:
    digit=n%10
    if digit>max:
        max=digit
    n=n//10
print(max)
# Out:
# 9

# %% [markdown]
# ### Q59. Find the smallest digit
# **Topic:** Digit Manipulation | **Level:** Medium

# %%
n=987491
min=9
while n>0:
    digit=n%10
    if digit<min:
        min=digit
    n=n//10
print(min)# your code here
# Out:
# 1

# %% [markdown]
# ### Q60. Count even digits
# **Topic:** Digit Manipulation | **Level:** Easy

# %%
n=123456
count=0
while n>0:
    digit=n%10
    if digit%2==0:
        count+=1
    n=n//10  
print (count)
# Out:
# 3

# %% [markdown]
# ### Q61. Count odd digits
# **Topic:** Digit Manipulation | **Level:** Easy

# %%
n=135642
count=0
while n>0:
    digit=n%10
    if digit%2!=0 :
        count+=1
    n=n//10
print(count)
# Out:
# 3

# %% [markdown]
# ### Q62. Check if all digits are even
# **Topic:** Digit Manipulation | **Level:** Medium

# %%
n=24
flag=True
while n>0:
    digit=n%10
    if digit %2!=0:
     flag=False
    break
n=n//10
if flag:
        print("digits are even")
else:
        print("digits are odd")
# Out:
# digits are even

# %% [markdown]
# ### Q63. Check if all digits are odd
# **Topic:** Digit Manipulation | **Level:** Medium

# %%
n=135
flag=True
while n>0:
    digit=n%10
    if digit%2==0:
        flag=False
        break
    n=n//10
if flag:
    print("odd numbers")
else:
    print("even")
# Out:
# odd numbers

# %% [markdown]
# ### Q64. Count occurrences of digit 0
# **Topic:** Digit Manipulation | **Level:** Medium

# %%
n=1001230
count=0
while n>0:
    digit=n%10
    if digit==0:
     count+=1
    n=n//10
print(count)
# Out:
# 3

# %% [markdown]
# ### Q65. Count occurrences of digit 5
# **Topic:** Digit Manipulation | **Level:** Medium

# %%
n=553455
count=0
while n>0:
    digit=n%10
    if digit ==5:
     count+=1
    n=n//10
print(count)
# Out:
# 4

# %% [markdown]
# ### Q66. Count occurrences of digit 7
# **Topic:** Digit Manipulation | **Level:** Medium

# %%
n=171771
count=0
while n>0:
    digit=n%10
    if digit == 7:
     count+=1
    n=n//10
print(count)
# Out:
# 3

# %% [markdown]
# ### Q67. Check if a number contains digit 3
# **Topic:** Digit Manipulation | **Level:** Medium

# %%
n=121

while n>0:
    digit=n%10
    if digit == 3:
        print("3 exits")
    n=n//10

# %% [markdown]
# ### Q68. Find the sum of squares of digits
# **Topic:** Digit Manipulation | **Level:** Medium

# %%
n=123
sum=0
while n>0:
    digit=n%10
    sum=sum + digit**2
    n=n//10
print (sum)
# Out:
# 14

# %% [markdown]
# ### Q69. Find the sum of cubes of digits
# **Topic:** Digit Manipulation | **Level:** Medium

# %%
n=123
sum=0
while n>0:
    digit=n%10
    sum=sum + (digit**3)
    n=n//10
print(sum)
# Out:
# 36

# %% [markdown]
# ### Q70. Check if sum of digits is even
# **Topic:** Digit Manipulation | **Level:** Easy

# %%
n=246
sum=0
while n>0:
   digit=n%10
   sum+=digit
   n=n//10
if sum%2==0:
    print("sums of digits is even")
# Out:
# sums of digits is even

# %% [markdown]
# ### Q71. Check if sum of digits is odd
# **Topic:** Digit Manipulation | **Level:** Easy

# %%
n=135
sum=0
while n>0:
    digit=n%10
    sum+=digit
    n=n//10
if sum%2!=0:
    print("sum is odd")
# Out:
# sum is odd

# %% [markdown]
# ### Q72. Check whether first and last digits are equal
# **Topic:** Digit Manipulation | **Level:** Medium

# %%
n=512315
last=n%10
while n>=10:
    n=n//10
    first=n
    
    if first==last:
        print("first and last digit are same")
# Out:
# first and last digit are same

# %% [markdown]
# ### Q73. Check whether first digit is larger than last digit
# **Topic:** Digit Manipulation | **Level:** Medium

# %%
n=81987
last=n%10
while n>9:
    n=n//10
    first=n
if first >last:
        print("1st is greater than last")
# Out:
# 1st is greater than last

# %% [markdown]
# ### Q74. Find the difference between first and last digit
# **Topic:** Digit Manipulation | **Level:** Medium

# %%
n=431
last=n%10
diff=0
while n>=10:
    n=n//10
    first=n
diff=first-last
print(diff)
# Out:
# 3

# %% [markdown]
# ### Q75. Check if all digits are the same
# **Topic:** Digit Manipulation | **Level:** Medium

# %%
n=22223
ref=n%10
flag=True

while n>0:
    digit=n%10
  
    if digit!=ref:
        flag=False
        break
    
    n=n//10
if flag:
    print("all digits are same")
else:
    print("not equal")
# Out:
# not equal

# %% [markdown]
# ### Q76. Count the number of zeros in a number
# **Topic:** Digit Manipulation | **Level:** Medium

# %%
n=10020000
count=0
while n>0:
    digit=n%10
    if digit ==0:
        count+=1
    n=n//10
print(count)
# Out:
# 6

# %% [markdown]
# ### Q77. Count digits greater than 5
# **Topic:** Digit Manipulation | **Level:** Medium

# %%
n=567
count=0
while n>0:
    digit=n%10
    if digit >=5:
        count+=1
    n=n//10
print(count)
# Out:
# 3

# %% [markdown]
# ### Q78. Count digits less than 5
# **Topic:** Digit Manipulation | **Level:** Medium

# %%
n=123451
count=0
while n>0:
    digit=n%10
    if digit<5:
        count+=1
    n=n//10
print(count)
# Out:
# 5

# %% [markdown]
# ### Q79. Check whether digits are in increasing order
# **Topic:** Digit Manipulation | **Level:** Hard

# %%
n=123456
prev=n%10
n=n//10
flag=True
while n>0:
    digit=n%10
    if digit >prev:
        flag=False
        break
    prev=digit
    n=n//10
if flag:
        print("they are in increasing order")
else:
        print("they are not in increasing order")
# Out:
# they are in increasing order

# %% [markdown]
# ### Q80. Check whether digits are in decreasing order
# **Topic:** Digit Manipulation | **Level:** Hard

# %%
n=87641
prev=n%10
n=n//10
flag=True
while n>0:
    digit=n%10
    if digit<prev:
        flag=False
        break
        prev=digit

    n=n//10
if flag:
    print("decreasing order")
else:
        print("not in decreasing order  ")
# Out:
# decreasinf order

# %% [markdown]
# ### Q81. Check if a number is prime
# **Topic:** Number Theory | **Level:** Medium

# %%
n=7
count=0
start=1
end=n
for i in range (start,end+1):
    if n%i==0:
        count+=1
if count==2:
 print("prime no.")
# Out:
# prime no.

# %% [markdown]
# ### Q82. Print all prime numbers up to N
# **Topic:** Number Theory | **Level:** Medium

# %%
n=20
for i in range (2,n+1):
    count =0
    for j in range(1,i+1):
        if i %j==0:
            count+=1
    if count==2:
      print(i)
# Out:
# 2
# 3
# 5
# 7
# 11
# 13
# 17
# 19

# %% [markdown]
# ### Q83. Count prime numbers up to N
# **Topic:** Number Theory | **Level:** Medium

# %%
n=7
prime_count=0
for  i in  range(1,n+1):
    count=0
    for  j in range (1,i+1):
        if i %j==0 :
            count+=1
    if count==2:
         prime_count+=1
         print(i)
print(prime_count , "is the count")
# Out:
# 2
# 3
# 5
# 7
# 4 is the count

# %% [markdown]
# ### Q84. Find the next prime after N
# **Topic:** Number Theory | **Level:** Medium

# %%
n=11
num=n+1

while True:
    is_prime=True
    for i in range(2,int(num**0.5)+1):
        if num%i==0:
            is_prime=False
            break
    if is_prime==True:
     print(num)
     break
    num=num+1
# Out:
# 13

# %% [markdown]
# ### Q85. Find all factors of a number
# **Topic:** Number Theory | **Level:** Easy

# %%
n=12

start=1
end=n+1
for i in range (start,end+1):
    if n%i==0:
        print(i)
# Out:
# 1
# 2
# 3
# 4
# 6
# 12

# %% [markdown]
# ### Q86. Count factors of a number
# **Topic:** Number Theory | **Level:** Medium

# %%
n=12
count=0
for i in range(1,n+1):
    if n %i ==0:
        count+=1
        
print (count)
# Out:
# 6

# %% [markdown]
# ### Q87. Check if a number is a perfect square
# **Topic:** Number Theory | **Level:** Medium

# %%
n=9
root=int(n**0.5)
if root *root==n:
    print("square number",n)
# Out:
# square number 9

# %% [markdown]
# ### Q88. Check if a number is a perfect cube
# **Topic:** Number Theory | **Level:** Medium

# %%
n=8
flag=False
for i in range (1,n+1):
    if i**3==n:
       flag=True
       break
if flag:
        print("perfect cube number",n)
else:
            print("not")
# Out:
# perfect cube number 8

# %% [markdown]
# ### Q89. Check if a number is an Armstrong number
# **Topic:** Number Theory | **Level:** Hard

# %%
n=153
temp=n
sum=0
while temp >0:
    digit=temp%10
    sum+=digit**3
    temp=temp//10
if sum==n:
    print("its a armstromng no.")
# Out:
# its a armstromng no.

# %% [markdown]
# ### Q90. Check if a number is a Harshad number
# **Topic:** Number Theory | **Level:** Hard

# %%
n=18
temp=n
sum=0
while temp>0:
    digit=temp%10
    sum+=digit
    temp=temp//10
if n%sum==0:
    print(n,"is harshad number")
else:
    print("not")
# Out:
# 18 is harshad number

# %% [markdown]
# ### Q91. Check if a number is composite
# **Topic:** Number Theory | **Level:** Medium

# %%
n=70
flag=False

for i in range(2,int(n**0.5)+1):
        if n%i==0:
            flag=True
            break
if  n > 1 and flag:
    print("compo no.")
# Out:
# compo no.

# %% [markdown]
# ### Q92. Find GCD of two numbers
# **Topic:** Number Theory | **Level:** Medium

# %%
a=12
b=18
small_no=0
if a<b :
    small_no=a
else:
    small_no=b

for i in  range (small_no,0,-1):
    if a%i==0 and b%i==0:
        print(i,"is the gcd no.")
        break
# Out:
# 6 is the gcd no.

# %% [markdown]
# ### Q93. Find LCM of two numbers
# **Topic:** Number Theory | **Level:** Medium

# %%
a=18
b=12
lcm=max(a,b)
while True:
    if lcm %a==0 and lcm%b==0:
        print(lcm,"is lcm")
        break
    lcm+=1
# Out:
# 36 is lcm

# %% [markdown]
# ### Q94. Check if two numbers are co-prime
# **Topic:** Number Theory | **Level:** Medium

# %%
a=8
b=15
small_no=0
if a<b:
    small_no=a
else:
    small_no=b
for i in range(small_no,0,-1):
    if a%i==0 and b%i==0:
        
        break
if i==1:
    print(a, b , "are co-prime")
# Out:
# 8 15 are co-prime

# %% [markdown]
# ### Q95. Find factorial of a number
# **Topic:** Number Theory | **Level:** Easy

# %%
n=4
fact=1
for i in range(n,1,-1):
   fact= fact*i
print (fact)
# Out:
# 24

# %% [markdown]
# ### Q96. Find the nth Fibonacci number
# **Topic:** Number Theory | **Level:** Medium

# %%
n=5
first=0
second=1
if n==1:
    print(first)
elif n==2:
    print(second)
else:
    for i in range(3,n+1):
        next=first+second
        first=second
        second=next
    print(second)
# Out:
# 3

# %% [markdown]
# ### Q97. Print Fibonacci series up to N terms
# **Topic:** Number Theory | **Level:** Medium

# %%
kjhhbjk

# %% [markdown]
# ### Q98. Check if a number belongs to Fibonacci sequence
# **Topic:** Number Theory | **Level:** Hard

# %%
# your code here

# %% [markdown]
# ### Q99. Check if a number is a power of 2
# **Topic:** Number Theory | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q100. Check if a number is a power of 3
# **Topic:** Number Theory | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q101. Find the sum of factorials from 1 to N
# **Topic:** Loops + Math | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q102. Find the product of odd numbers from 1 to N
# **Topic:** Loops + Math | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q103. Find the sum of prime numbers up to N
# **Topic:** Number Theory | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q104. Count Armstrong numbers in a range
# **Topic:** Number Theory | **Level:** Hard

# %%
# your code here

# %% [markdown]
# ### Q105. Count palindrome numbers in a range
# **Topic:** Digit Manipulation | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q106. Print factors common to two numbers
# **Topic:** Number Theory | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q107. Count common factors of two numbers
# **Topic:** Number Theory | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q108. Find largest digit and its frequency
# **Topic:** Digit Manipulation | **Level:** Hard

# %%
# your code here

# %% [markdown]
# ### Q109. Find smallest digit and its frequency
# **Topic:** Digit Manipulation | **Level:** Hard

# %%
# your code here

# %% [markdown]
# ### Q110. Find sum of even digits
# **Topic:** Digit Manipulation | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q111. Find sum of odd digits
# **Topic:** Digit Manipulation | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q112. Find product of even digits
# **Topic:** Digit Manipulation | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q113. Find product of odd digits
# **Topic:** Digit Manipulation | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q114. Check if a number ends with an even digit
# **Topic:** Digit Manipulation | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q115. Check if first digit is odd
# **Topic:** Digit Manipulation | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q116. Find the largest factor excluding itself
# **Topic:** Number Theory | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q117. Find the smallest factor greater than 1
# **Topic:** Number Theory | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q118. Count multiples of 7 in a range
# **Topic:** Loops | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q119. Count perfect squares in a range
# **Topic:** Loops | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q120. Count perfect cubes in a range
# **Topic:** Loops | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q121. Print a right triangle using numbers
# **Topic:** Nested Loops | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q122. Print an inverted number triangle
# **Topic:** Nested Loops | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q123. Print multiplication table of a number
# **Topic:** Loops | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q124. Print multiplication tables from 1 to N
# **Topic:** Nested Loops | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q125. Find sum of multiplication table values
# **Topic:** Loops | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q126. Check if a number is triangular
# **Topic:** Number Theory | **Level:** Hard

# %%
# your code here

# %% [markdown]
# ### Q127. Check if a number is a neon number
# **Topic:** Number Theory | **Level:** Hard

# %%
# your code here

# %% [markdown]
# ### Q128. Check if a number is a spy number
# **Topic:** Number Theory | **Level:** Hard

# %%
# your code here

# %% [markdown]
# ### Q129. Check if a number is a duck number
# **Topic:** Digit Manipulation | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q130. Count numbers containing digit 7 in a range
# **Topic:** Digit Manipulation | **Level:** Hard

# %%
# your code here

# %% [markdown]
# ### Q131. Find reverse and compare with original
# **Topic:** Digit Manipulation | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q132. Find absolute difference between number and reverse
# **Topic:** Digit Manipulation | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q133. Check if reverse is greater than original
# **Topic:** Digit Manipulation | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q134. Count digits equal to first digit
# **Topic:** Digit Manipulation | **Level:** Hard

# %%
# your code here

# %% [markdown]
# ### Q135. Count digits equal to last digit
# **Topic:** Digit Manipulation | **Level:** Hard

# %%
# your code here

# %% [markdown]
# ### Q136. Find sum of first and last digit
# **Topic:** Digit Manipulation | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q137. Find product of first and last digit
# **Topic:** Digit Manipulation | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q138. Check if sum of digits equals product of digits
# **Topic:** Digit Manipulation | **Level:** Hard

# %%
# your code here

# %% [markdown]
# ### Q139. Find the digital root of a number
# **Topic:** Number Theory | **Level:** Hard

# %%
# your code here

# %% [markdown]
# ### Q140. Count steps needed to reduce a number to 1
# **Topic:** Simulation | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q141. Simulate repeated division by 2 until 1
# **Topic:** Simulation | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q142. Count how many times a number can be divided by 2
# **Topic:** Simulation | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q143. Find the largest power of 2 less than N
# **Topic:** Number Theory | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q144. Find the largest power of 3 less than N
# **Topic:** Number Theory | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q145. Find all divisors whose digit sum is even
# **Topic:** Mixed Logic | **Level:** Hard

# %%
# your code here

# %% [markdown]
# ### Q146. Find all divisors whose digit sum is odd
# **Topic:** Mixed Logic | **Level:** Hard

# %%
# your code here

# %% [markdown]
# ### Q147. Check if every digit is prime (2,3,5,7)
# **Topic:** Digit Manipulation | **Level:** Hard

# %%
# your code here

# %% [markdown]
# ### Q148. Count prime digits in a number
# **Topic:** Digit Manipulation | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q149. Find the sum of prime digits in a number
# **Topic:** Digit Manipulation | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q150. Build a simple calculator using two numbers and an operation choice
# **Topic:** Conditional Statements | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q151. Check if a number is a strong number
# **Topic:** Number Theory | **Level:** Hard

# %%
# your code here

# %% [markdown]
# ### Q152. Count strong numbers in a range
# **Topic:** Number Theory | **Level:** Hard

# %%
# your code here

# %% [markdown]
# ### Q153. Check if a number is a perfect number
# **Topic:** Number Theory | **Level:** Hard

# %%
# your code here

# %% [markdown]
# ### Q154. Print all perfect numbers up to N
# **Topic:** Number Theory | **Level:** Hard

# %%
# your code here

# %% [markdown]
# ### Q155. Check if a number is an abundant number
# **Topic:** Number Theory | **Level:** Hard

# %%
# your code here

# %% [markdown]
# ### Q156. Check if a number is a deficient number
# **Topic:** Number Theory | **Level:** Hard

# %%
# your code here

# %% [markdown]
# ### Q157. Find the sum of all factors of a number
# **Topic:** Number Theory | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q158. Find the product of all factors of a number
# **Topic:** Number Theory | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q159. Count even factors of a number
# **Topic:** Number Theory | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q160. Count odd factors of a number
# **Topic:** Number Theory | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q161. Find the largest prime factor of a number
# **Topic:** Number Theory | **Level:** Hard

# %%
# your code here

# %% [markdown]
# ### Q162. Find the smallest prime factor of a number
# **Topic:** Number Theory | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q163. Check if a number is semiprime
# **Topic:** Number Theory | **Level:** Hard

# %%
# your code here

# %% [markdown]
# ### Q164. Count semiprime numbers in a range
# **Topic:** Number Theory | **Level:** Hard

# %%
# your code here

# %% [markdown]
# ### Q165. Find the sum of prime factors of a number
# **Topic:** Number Theory | **Level:** Hard

# %%
# your code here

# %% [markdown]
# ### Q166. Find the product of prime factors of a number
# **Topic:** Number Theory | **Level:** Hard

# %%
# your code here

# %% [markdown]
# ### Q167. Check if a number can be expressed as the sum of two primes
# **Topic:** Number Theory | **Level:** Hard

# %%
# your code here

# %% [markdown]
# ### Q168. Count prime digits and non-prime digits in a number
# **Topic:** Digit Manipulation | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q169. Find the largest prime digit in a number
# **Topic:** Digit Manipulation | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q170. Find the smallest prime digit in a number
# **Topic:** Digit Manipulation | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q171. Check if every digit is unique
# **Topic:** Digit Manipulation | **Level:** Hard

# %%
# your code here

# %% [markdown]
# ### Q172. Count distinct digits in a number
# **Topic:** Digit Manipulation | **Level:** Hard

# %%
# your code here

# %% [markdown]
# ### Q173. Find the frequency of the first digit
# **Topic:** Digit Manipulation | **Level:** Hard

# %%
# your code here

# %% [markdown]
# ### Q174. Find the frequency of the last digit
# **Topic:** Digit Manipulation | **Level:** Hard

# %%
# your code here

# %% [markdown]
# ### Q175. Check whether a number contains consecutive identical digits
# **Topic:** Digit Manipulation | **Level:** Hard

# %%
# your code here

# %% [markdown]
# ### Q176. Find the longest run of the same digit
# **Topic:** Digit Manipulation | **Level:** Hard

# %%
# your code here

# %% [markdown]
# ### Q177. Check whether alternating digits are even and odd
# **Topic:** Digit Manipulation | **Level:** Hard

# %%
# your code here

# %% [markdown]
# ### Q178. Check if every digit is greater than the previous digit
# **Topic:** Digit Manipulation | **Level:** Hard

# %%
# your code here

# %% [markdown]
# ### Q179. Check if every digit is smaller than the previous digit
# **Topic:** Digit Manipulation | **Level:** Hard

# %%
# your code here

# %% [markdown]
# ### Q180. Find the difference between the largest and smallest digit
# **Topic:** Digit Manipulation | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q181. Print all factors in ascending order
# **Topic:** Loops + Factors | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q182. Print all factors in descending order
# **Topic:** Loops + Factors | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q183. Count numbers divisible by exactly three factors in a range
# **Topic:** Number Theory | **Level:** Hard

# %%
# your code here

# %% [markdown]
# ### Q184. Find the first prime number greater than N
# **Topic:** Number Theory | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q185. Find the first composite number greater than N
# **Topic:** Number Theory | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q186. Find the nearest multiple of 10 to a number
# **Topic:** Conditional Statements | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q187. Check whether a number is closer to the previous or next multiple of 10
# **Topic:** Conditional Statements | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q188. Find the nearest perfect square to a number
# **Topic:** Number Theory | **Level:** Hard

# %%
# your code here

# %% [markdown]
# ### Q189. Find the nearest perfect cube to a number
# **Topic:** Number Theory | **Level:** Hard

# %%
# your code here

# %% [markdown]
# ### Q190. Count numbers ending in 5 within a range
# **Topic:** Loops | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q191. Count numbers ending in an even digit within a range
# **Topic:** Loops | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q192. Count numbers ending in an odd digit within a range
# **Topic:** Loops | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q193. Find the sum of all palindrome numbers in a range
# **Topic:** Digit Manipulation | **Level:** Hard

# %%
# your code here

# %% [markdown]
# ### Q194. Count numbers whose digit sum is divisible by 3 in a range
# **Topic:** Digit Manipulation | **Level:** Hard

# %%
# your code here

# %% [markdown]
# ### Q195. Count numbers whose digit sum is divisible by 5 in a range
# **Topic:** Digit Manipulation | **Level:** Hard

# %%
# your code here

# %% [markdown]
# ### Q196. Find the smallest palindrome number greater than N
# **Topic:** Digit Manipulation | **Level:** Hard

# %%
# your code here

# %% [markdown]
# ### Q197. Find the largest palindrome number smaller than N
# **Topic:** Digit Manipulation | **Level:** Hard

# %%
# your code here

# %% [markdown]
# ### Q198. Simulate compound growth for N years using loops
# **Topic:** Simulation | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q199. Simulate repeated doubling until a target value is reached
# **Topic:** Simulation | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q200. Find the number of steps required to reach a target using fixed increments
# **Topic:** Simulation | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q201. Print a pyramid of *
# **Topic:** Pattern Printing | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q202. Print an inverted pyramid of *
# **Topic:** Pattern Printing | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q203. Print a hollow square pattern
# **Topic:** Pattern Printing | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q204. Print a hollow rectangle pattern
# **Topic:** Pattern Printing | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q205. Print Floyd's Triangle
# **Topic:** Pattern Printing | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q206. Print a triangle of consecutive odd numbers
# **Topic:** Pattern Printing | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q207. Print a triangle of consecutive even numbers
# **Topic:** Pattern Printing | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q208. Print a triangle with alternating 0 and 1
# **Topic:** Pattern Printing | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q209. Print a square with increasing numbers column-wise
# **Topic:** Pattern Printing | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q210. Print an X pattern using *
# **Topic:** Pattern Printing | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q211. Print a diamond pattern of *
# **Topic:** Pattern Printing | **Level:** Hard

# %%
# your code here

# %% [markdown]
# ### Q212. Print a hollow triangle pattern
# **Topic:** Pattern Printing | **Level:** Hard

# %%
# your code here

# %% [markdown]
# ### Q213. Print Pascal's Triangle
# **Topic:** Pattern Printing | **Level:** Hard

# %%
# your code here

# %% [markdown]
# ### Q214. Print a butterfly pattern
# **Topic:** Pattern Printing | **Level:** Hard

# %%
# your code here

# %% [markdown]
# ### Q215. Print a sandglass pattern
# **Topic:** Pattern Printing | **Level:** Hard

# %%
# your code here

# %% [markdown]
# ### Q216. Print a palindromic number pyramid
# **Topic:** Pattern Printing | **Level:** Hard

# %%
# your code here

# %% [markdown]
# ### Q217. Print a hollow pyramid
# **Topic:** Pattern Printing | **Level:** Hard

# %%
# your code here

# %% [markdown]
# ### Q218. Print a hollow inverted pyramid
# **Topic:** Pattern Printing | **Level:** Hard

# %%
# your code here

# %% [markdown]
# ### Q219. Print a concentric square pattern of numbers
# **Topic:** Pattern Printing | **Level:** Hard

# %%
# your code here

# %% [markdown]
# ### Q220. Print a concentric rectangular pattern
# **Topic:** Pattern Printing | **Level:** Hard

# %%
# your code here

# %% [markdown]
# ### Q221. Count the number of characters in a string
# **Topic:** Strings | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q222. Count the number of vowels in a string
# **Topic:** Strings | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q223. Count the number of consonants in a string
# **Topic:** Strings | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q224. Count the number of uppercase letters
# **Topic:** Strings | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q225. Count the number of lowercase letters
# **Topic:** Strings | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q226. Count the number of digits in a string
# **Topic:** Strings | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q227. Count the number of spaces in a string
# **Topic:** Strings | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q228. Count the number of special characters
# **Topic:** Strings | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q229. Count how many times a given character occurs
# **Topic:** Strings | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q230. Check if a character exists in a string
# **Topic:** Strings | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q231. Print all characters one per line
# **Topic:** Strings | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q232. Print characters at even indices
# **Topic:** Strings | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q233. Print characters at odd indices
# **Topic:** Strings | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q234. Find the first character of a string
# **Topic:** Strings | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q235. Find the last character of a string
# **Topic:** Strings | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q236. Reverse a string
# **Topic:** Strings | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q237. Check if a string is a palindrome
# **Topic:** Strings | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q238. Count the number of words in a string
# **Topic:** Strings | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q239. Find the first vowel in a string
# **Topic:** Strings | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q240. Find the last vowel in a string
# **Topic:** Strings | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q241. Count how many times 'a' appears in a string
# **Topic:** Strings | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q242. Count how many vowels are present at even indices
# **Topic:** Strings | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q243. Count how many vowels are present at odd indices
# **Topic:** Strings | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q244. Print only the vowels from a string
# **Topic:** Strings | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q245. Print only the consonants from a string
# **Topic:** Strings | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q246. Convert all lowercase letters to uppercase without using built-in methods
# **Topic:** Strings | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q247. Convert all uppercase letters to lowercase without using built-in methods
# **Topic:** Strings | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q248. Toggle the case of every character
# **Topic:** Strings | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q249. Count how many words start with a vowel
# **Topic:** Strings | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q250. Count how many words end with a vowel
# **Topic:** Strings | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q251. Find the longest word in a string
# **Topic:** Strings | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q252. Find the shortest word in a string
# **Topic:** Strings | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q253. Find the length of the longest word
# **Topic:** Strings | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q254. Find the length of the shortest word
# **Topic:** Strings | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q255. Remove all spaces from a string
# **Topic:** Strings | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q256. Replace every space with '-'
# **Topic:** Strings | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q257. Count consecutive repeated characters
# **Topic:** Strings | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q258. Find the character with the maximum frequency
# **Topic:** Strings | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q259. Find the character with the minimum frequency
# **Topic:** Strings | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q260. Check if two strings are anagrams
# **Topic:** Strings | **Level:** Hard

# %%
# your code here

# %% [markdown]
# ### Q261. Check if one string is a substring of another
# **Topic:** Strings | **Level:** Hard

# %%
# your code here

# %% [markdown]
# ### Q262. Count occurrences of a substring
# **Topic:** Strings | **Level:** Hard

# %%
# your code here

# %% [markdown]
# ### Q263. Find the first occurrence of a substring
# **Topic:** Strings | **Level:** Hard

# %%
# your code here

# %% [markdown]
# ### Q264. Find the last occurrence of a substring
# **Topic:** Strings | **Level:** Hard

# %%
# your code here

# %% [markdown]
# ### Q265. Find the longest sequence of repeated characters
# **Topic:** Strings | **Level:** Hard

# %%
# your code here

# %% [markdown]
# ### Q266. Check if all characters in a string are unique
# **Topic:** Strings | **Level:** Hard

# %%
# your code here

# %% [markdown]
# ### Q267. Find the first non-repeating character
# **Topic:** Strings | **Level:** Hard

# %%
# your code here

# %% [markdown]
# ### Q268. Find the first repeating character
# **Topic:** Strings | **Level:** Hard

# %%
# your code here

# %% [markdown]
# ### Q269. Perform basic run-length encoding (e.g., aaabb → a3b2)
# **Topic:** Strings | **Level:** Hard

# %%
# your code here

# %% [markdown]
# ### Q270. Check if a string can become a palindrome by removing exactly one character
# **Topic:** Strings | **Level:** Hard

# %%
# your code here

# %% [markdown]
# ### Q271. Print all elements of a list
# **Topic:** Lists | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q272. Find the length of a list
# **Topic:** Lists | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q273. Print the first element
# **Topic:** Lists | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q274. Print the last element
# **Topic:** Lists | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q275. Find the sum of all elements
# **Topic:** Lists | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q276. Find the maximum element
# **Topic:** Lists | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q277. Find the minimum element
# **Topic:** Lists | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q278. Count even numbers
# **Topic:** Lists | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q279. Count odd numbers
# **Topic:** Lists | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q280. Print all positive numbers
# **Topic:** Lists | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q281. Print all negative numbers
# **Topic:** Lists | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q282. Search for a given element
# **Topic:** Lists | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q283. Count occurrences of an element
# **Topic:** Lists | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q284. Reverse a list
# **Topic:** Lists | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q285. Find average of elements
# **Topic:** Lists | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q286. Print elements at even indices
# **Topic:** Lists | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q287. Print elements at odd indices
# **Topic:** Lists | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q288. Sum elements at even indices
# **Topic:** Lists | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q289. Sum elements at odd indices
# **Topic:** Lists | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q290. Find second largest element
# **Topic:** Lists | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q291. Find second smallest element
# **Topic:** Lists | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q292. Remove duplicates
# **Topic:** Lists | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q293. Print unique elements
# **Topic:** Lists | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q294. Count unique elements
# **Topic:** Lists | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q295. Move all zeros to the end
# **Topic:** Lists | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q296. Move all zeros to the beginning
# **Topic:** Lists | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q297. Separate even and odd elements
# **Topic:** Lists | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q298. Find difference between max and min
# **Topic:** Lists | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q299. Count elements greater than average
# **Topic:** Lists | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q300. Count elements less than average
# **Topic:** Lists | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q301. Rotate list left by 1
# **Topic:** Lists | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q302. Rotate list right by 1
# **Topic:** Lists | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q303. Rotate list left by K positions
# **Topic:** Lists | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q304. Rotate list right by K positions
# **Topic:** Lists | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q305. Check if list is sorted
# **Topic:** Lists | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q306. Check if list is strictly increasing
# **Topic:** Lists | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q307. Check if list is strictly decreasing
# **Topic:** Lists | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q308. Merge two lists
# **Topic:** Lists | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q309. Find common elements of two lists
# **Topic:** Lists | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q310. Find elements present only in first list
# **Topic:** Lists | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q311. Find elements present only in second list
# **Topic:** Lists | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q312. Find union of two lists
# **Topic:** Lists | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q313. Find intersection of two lists
# **Topic:** Lists | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q314. Find frequency of each element
# **Topic:** Lists | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q315. Find mode of a list
# **Topic:** Lists | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q316. Find median of a list
# **Topic:** Lists | **Level:** Hard

# %%
# your code here

# %% [markdown]
# ### Q317. Sort a list using bubble sort
# **Topic:** Lists | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q318. Sort a list using selection sort
# **Topic:** Lists | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q319. Sort a list using insertion sort
# **Topic:** Lists | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q320. Find largest consecutive increasing segment
# **Topic:** Lists | **Level:** Hard

# %%
# your code here

# %% [markdown]
# ### Q321. Find largest consecutive decreasing segment
# **Topic:** Lists | **Level:** Hard

# %%
# your code here

# %% [markdown]
# ### Q322. Remove consecutive duplicates
# **Topic:** Lists | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q323. Find first repeating element
# **Topic:** Lists | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q324. Find first non-repeating element
# **Topic:** Lists | **Level:** Hard

# %%
# your code here

# %% [markdown]
# ### Q325. Count pairs with even sum
# **Topic:** Lists | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q326. Count pairs with odd sum
# **Topic:** Lists | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q327. Find all pairs with target sum
# **Topic:** Lists | **Level:** Hard

# %%
# your code here

# %% [markdown]
# ### Q328. Find all triplets with target sum
# **Topic:** Lists | **Level:** Hard

# %%
# your code here

# %% [markdown]
# ### Q329. Check if list is palindrome
# **Topic:** Lists | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q330. Find smallest missing positive number
# **Topic:** Lists | **Level:** Hard

# %%
# your code here

# %% [markdown]
# ### Q331. Replace every element with its rank
# **Topic:** Lists | **Level:** Hard

# %%
# your code here

# %% [markdown]
# ### Q332. Create cumulative sum list
# **Topic:** Lists | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q333. Create running maximum list
# **Topic:** Lists | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q334. Create running minimum list
# **Topic:** Lists | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q335. Interleave two lists
# **Topic:** Lists | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q336. Split list into two halves
# **Topic:** Lists | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q337. Swap adjacent elements
# **Topic:** Lists | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q338. Find longest repeated element segment
# **Topic:** Lists | **Level:** Hard

# %%
# your code here

# %% [markdown]
# ### Q339. Find majority element (> n/2 occurrences)
# **Topic:** Lists | **Level:** Hard

# %%
# your code here

# %% [markdown]
# ### Q340. Find equilibrium index
# **Topic:** Lists | **Level:** Hard

# %%
# your code here

# %% [markdown]
# ### Q341. Create a tuple and print its elements
# **Topic:** Tuples | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q342. Find length of a tuple
# **Topic:** Tuples | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q343. Access first element
# **Topic:** Tuples | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q344. Access last element
# **Topic:** Tuples | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q345. Count occurrences of an element
# **Topic:** Tuples | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q346. Find maximum element
# **Topic:** Tuples | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q347. Find minimum element
# **Topic:** Tuples | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q348. Find sum of elements
# **Topic:** Tuples | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q349. Check if element exists
# **Topic:** Tuples | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q350. Convert tuple to list
# **Topic:** Tuples | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q351. Convert list to tuple
# **Topic:** Tuples | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q352. Concatenate two tuples
# **Topic:** Tuples | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q353. Slice a tuple
# **Topic:** Tuples | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q354. Reverse a tuple
# **Topic:** Tuples | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q355. Find second largest element
# **Topic:** Tuples | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q356. Remove duplicates from tuple values
# **Topic:** Tuples | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q357. Find common elements in two tuples
# **Topic:** Tuples | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q358. Check if tuple is palindrome
# **Topic:** Tuples | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q359. Sort tuple values
# **Topic:** Tuples | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q360. Find frequency of each element
# **Topic:** Tuples | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q361. Create a set and print elements
# **Topic:** Sets | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q362. Add an element to a set
# **Topic:** Sets | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q363. Remove an element from a set
# **Topic:** Sets | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q364. Check membership in a set
# **Topic:** Sets | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q365. Find union of two sets
# **Topic:** Sets | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q366. Find intersection of two sets
# **Topic:** Sets | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q367. Find difference of two sets
# **Topic:** Sets | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q368. Find symmetric difference
# **Topic:** Sets | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q369. Check subset relationship
# **Topic:** Sets | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q370. Check superset relationship
# **Topic:** Sets | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q371. Count unique elements in a list using set
# **Topic:** Sets | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q372. Remove duplicates using set
# **Topic:** Sets | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q373. Find common elements among three sets
# **Topic:** Sets | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q374. Find elements unique to first set
# **Topic:** Sets | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q375. Check if two sets are disjoint
# **Topic:** Sets | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q376. Find missing values between two sets
# **Topic:** Sets | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q377. Find repeated values using sets
# **Topic:** Sets | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q378. Count distinct characters in a string
# **Topic:** Sets | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q379. Find unique vowels in a string
# **Topic:** Sets | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q380. Check if all characters are unique
# **Topic:** Sets | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q381. Find common characters between two strings
# **Topic:** Sets | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q382. Find unique words in a sentence
# **Topic:** Sets | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q383. Find union of multiple sets
# **Topic:** Sets | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q384. Find intersection of multiple sets
# **Topic:** Sets | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q385. Find Jaccard similarity of two sets
# **Topic:** Sets | **Level:** Hard

# %%
# your code here

# %% [markdown]
# ### Q386. Create a dictionary and print keys and values
# **Topic:** Dictionaries | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q387. Access value using key
# **Topic:** Dictionaries | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q388. Add a new key-value pair
# **Topic:** Dictionaries | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q389. Update value of a key
# **Topic:** Dictionaries | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q390. Delete a key
# **Topic:** Dictionaries | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q391. Check if key exists
# **Topic:** Dictionaries | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q392. Print all keys
# **Topic:** Dictionaries | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q393. Print all values
# **Topic:** Dictionaries | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q394. Count frequency of numbers in a list
# **Topic:** Dictionaries | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q395. Count frequency of characters in a string
# **Topic:** Dictionaries | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q396. Find character with maximum frequency
# **Topic:** Dictionaries | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q397. Find character with minimum frequency
# **Topic:** Dictionaries | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q398. Find word frequencies in a sentence
# **Topic:** Dictionaries | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q399. Invert a dictionary
# **Topic:** Dictionaries | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q400. Merge two dictionaries
# **Topic:** Dictionaries | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q401. Find common keys in two dictionaries
# **Topic:** Dictionaries | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q402. Find keys present only in first dictionary
# **Topic:** Dictionaries | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q403. Sum all dictionary values
# **Topic:** Dictionaries | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q404. Find key with maximum value
# **Topic:** Dictionaries | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q405. Find key with minimum value
# **Topic:** Dictionaries | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q406. Group numbers by parity using a dictionary
# **Topic:** Dictionaries | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q407. Group words by length
# **Topic:** Dictionaries | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q408. Build a phone book application
# **Topic:** Dictionaries | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q409. Store student marks and find topper
# **Topic:** Dictionaries | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q410. Count occurrences of words in a paragraph
# **Topic:** Dictionaries | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q411. Build a simple inventory tracker
# **Topic:** Dictionaries | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q412. Find duplicate values in a dictionary
# **Topic:** Dictionaries | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q413. Sort dictionary by keys
# **Topic:** Dictionaries | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q414. Sort dictionary by values
# **Topic:** Dictionaries | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q415. Build a character-position map
# **Topic:** Dictionaries | **Level:** Hard

# %%
# your code here

# %% [markdown]
# ### Q416. Group numbers by remainder when divided by 3
# **Topic:** Dictionaries | **Level:** Hard

# %%
# your code here

# %% [markdown]
# ### Q417. Find the first non-repeating character using a dictionary
# **Topic:** Dictionaries | **Level:** Hard

# %%
# your code here

# %% [markdown]
# ### Q418. Build a histogram from numeric data
# **Topic:** Dictionaries | **Level:** Hard

# %%
# your code here

# %% [markdown]
# ### Q419. Implement a simple voting system using a dictionary
# **Topic:** Dictionaries | **Level:** Hard

# %%
# your code here

# %% [markdown]
# ### Q420. Build a word-frequency analyzer and report the top occurring word
# **Topic:** Dictionaries | **Level:** Hard

# %%
# your code here

# %% [markdown]
# ### Q421. Write a function to print "Hello World"
# **Topic:** Functions | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q422. Write a function that accepts a number and prints whether it is even or odd
# **Topic:** Functions | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q423. Write a function to find the larger of two numbers
# **Topic:** Functions | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q424. Write a function to find the largest of three numbers
# **Topic:** Functions | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q425. Write a function to calculate the square of a number
# **Topic:** Functions | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q426. Write a function to calculate the cube of a number
# **Topic:** Functions | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q427. Write a function to find the factorial of a number
# **Topic:** Functions | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q428. Write a function to check whether a number is prime
# **Topic:** Functions | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q429. Write a function to count the digits in a number
# **Topic:** Functions | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q430. Write a function to find the sum of digits of a number
# **Topic:** Functions | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q431. Write a function to reverse a number
# **Topic:** Functions | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q432. Write a function to check whether a number is a palindrome
# **Topic:** Functions | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q433. Write a function to find the GCD of two numbers
# **Topic:** Functions | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q434. Write a function to find the LCM of two numbers
# **Topic:** Functions | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q435. Write a function that returns the nth Fibonacci number
# **Topic:** Functions | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q436. Write a function to check whether a year is a leap year
# **Topic:** Functions | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q437. Write a function that returns the largest digit in a number
# **Topic:** Functions | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q438. Write a function that returns the smallest digit in a number
# **Topic:** Functions | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q439. Write a function that takes a number and returns whether it is an Armstrong number
# **Topic:** Functions | **Level:** Hard

# %%
# your code here

# %% [markdown]
# ### Q440. Write a menu-driven program that uses separate functions for addition, subtraction, multiplication, and division
# **Topic:** Functions | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q441. Write a function that returns the sum of all numbers from 1 to N
# **Topic:** Functions | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q442. Write a function that returns the product of all numbers from 1 to N
# **Topic:** Functions | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q443. Write a function that returns the count of even digits in a number
# **Topic:** Functions | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q444. Write a function that returns the count of odd digits in a number
# **Topic:** Functions | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q445. Write a function that returns the first digit of a number
# **Topic:** Functions | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q446. Write a function that returns the last digit of a number
# **Topic:** Functions | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q447. Write a function that takes two numbers and returns the power of the first number raised to the second without using **
# **Topic:** Functions | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q448. Write a function that returns all factors of a number
# **Topic:** Functions | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q449. Write a function that checks whether a number is a perfect square
# **Topic:** Functions | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q450. Write a program using multiple functions where one function checks if a number is prime and another function prints all prime numbers up to N
# **Topic:** Functions | **Level:** Hard

# %%
# your code here

# %% [markdown]
# ### Q451. Write a recursive function to print numbers from 1 to N
# **Topic:** Recursion | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q452. Write a recursive function to print numbers from N to 1
# **Topic:** Recursion | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q453. Write a recursive function to find the sum of numbers from 1 to N
# **Topic:** Recursion | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q454. Write a recursive function to find the factorial of a number
# **Topic:** Recursion | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q455. Write a recursive function to calculate x raised to the power n
# **Topic:** Recursion | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q456. Write a recursive function to count the digits in a number
# **Topic:** Recursion | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q457. Write a recursive function to find the sum of digits of a number
# **Topic:** Recursion | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q458. Write a recursive function to find the product of digits of a number
# **Topic:** Recursion | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q459. Write a recursive function to reverse a number
# **Topic:** Recursion | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q460. Write a recursive function to check whether a number is a palindrome
# **Topic:** Recursion | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q461. Write a recursive function to find the nth Fibonacci number
# **Topic:** Recursion | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q462. Write a recursive function to find the GCD of two numbers using Euclid's algorithm
# **Topic:** Recursion | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q463. Write a recursive function to check whether a number is even or odd (without using loops)
# **Topic:** Recursion | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q464. Write a recursive function to find the largest digit in a number
# **Topic:** Recursion | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q465. Write a recursive function to find the smallest digit in a number
# **Topic:** Recursion | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q466. Write a recursive function to count occurrences of a specific digit in a number
# **Topic:** Recursion | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q467. Write a recursive function to check whether a number is prime
# **Topic:** Recursion | **Level:** Hard

# %%
# your code here

# %% [markdown]
# ### Q468. Write a recursive function to print all factors of a number
# **Topic:** Recursion | **Level:** Hard

# %%
# your code here

# %% [markdown]
# ### Q469. Write a recursive function to convert a decimal number to binary
# **Topic:** Recursion | **Level:** Hard

# %%
# your code here

# %% [markdown]
# ### Q470. Write a recursive function to solve the Tower of Hanoi problem for N disks
# **Topic:** Recursion | **Level:** Hard

# %%
# your code here

# %% [markdown]
# ### Q471. Perform a linear search to check whether an element exists in a list
# **Topic:** Searching | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q472. Find the index of a given element using linear search
# **Topic:** Searching | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q473. Find all indices of a given element
# **Topic:** Searching | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q474. Count how many times an element appears in a list
# **Topic:** Searching | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q475. Find the first occurrence of an element
# **Topic:** Searching | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q476. Find the last occurrence of an element
# **Topic:** Searching | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q477. Find the smallest element using traversal
# **Topic:** Searching | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q478. Find the largest element using traversal
# **Topic:** Searching | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q479. Find the second largest element using traversal
# **Topic:** Searching | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q480. Find the second smallest element using traversal
# **Topic:** Searching | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q481. Find the first even number in a list
# **Topic:** Searching | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q482. Find the first odd number in a list
# **Topic:** Searching | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q483. Find the first negative number in a list
# **Topic:** Searching | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q484. Find the first positive number in a list
# **Topic:** Searching | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q485. Perform binary search on a sorted list
# **Topic:** Searching | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q486. Find the first occurrence of an element using binary search
# **Topic:** Searching | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q487. Find the last occurrence of an element using binary search
# **Topic:** Searching | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q488. Count occurrences of an element in a sorted list using binary search
# **Topic:** Searching | **Level:** Hard

# %%
# your code here

# %% [markdown]
# ### Q489. Find the insertion position of an element in a sorted list
# **Topic:** Searching | **Level:** Hard

# %%
# your code here

# %% [markdown]
# ### Q490. Find the closest element to a target value in a sorted list
# **Topic:** Searching | **Level:** Hard

# %%
# your code here

# %% [markdown]
# ### Q491. Sort a list in ascending order using Bubble Sort
# **Topic:** Sorting | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q492. Sort a list in descending order using Bubble Sort
# **Topic:** Sorting | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q493. Sort a list in ascending order using Selection Sort
# **Topic:** Sorting | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q494. Sort a list in descending order using Selection Sort
# **Topic:** Sorting | **Level:** Easy

# %%
# your code here

# %% [markdown]
# ### Q495. Sort a list in ascending order using Insertion Sort
# **Topic:** Sorting | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q496. Sort a list in descending order using Insertion Sort
# **Topic:** Sorting | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q497. Sort a list containing only 0s and 1s
# **Topic:** Sorting | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q498. Sort a list so that all even numbers appear before odd numbers
# **Topic:** Sorting | **Level:** Medium

# %%
# your code here

# %% [markdown]
# ### Q499. Sort a list based on the frequency of elements (highest frequency first)
# **Topic:** Sorting | **Level:** Hard

# %%
# your code here

# %% [markdown]
# ### Q500. Compare Bubble Sort, Selection Sort, and Insertion Sort by counting the number of comparisons and swaps for the same input
# **Topic:** Sorting | **Level:** Hard

# %%
# your code here
